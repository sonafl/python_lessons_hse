# %% [markdown]
# # Задачи B

# %% [markdown]
# ## Задание 9

# %% [markdown]
# **1** Помогите бедному вышкинцу понять 10-балльную систему. Если студент получил оценку больше или равно 8, то у него 5, если получил от 6 до 7, то 4, если от 4 до 5, то 3. Вводится число в 10 балльной системе, вывести нужно число в 5-балльной.

# %% [markdown]
# **2** Напишите программу, которая сравнивает два целых числа a и b (эти переменные уже считаны для вас).
#
# Программа должна выводить большее число из двух.
# Если числа равны, программа должна выводить строку "Введенные числа равны" (строка сохранена в переменную equality)

# %% [markdown]
# **3** Вася - обычный студент. Поэтому он всегда голодный и хочет кофе. Напишите программу, которая поможет Васе понять, что он сможет купить себе в столовой. Если у Васи только 180 рублей, он может купить только обед, если у Васи больше 180, то он сможет купить и обед, и кофе. Если же у Васи меньше 180 рублей, он будет ждать стипу

# %% [markdown]
# **4** Петя хочет купит картину. Если сумма картины больше 10000, он ее не может купить и мы должны вывести строку "не могу". В остальных случаях - "могу купить"
#
# **5** Петя хочет купит картину. Если сумма картины меньше 10000 и в названии картины есть слово "море", он ее может купить и мы должны вывести строку "могу". В остальных случаях - " не могу купить"
#
# **6** Программа долждна проверять что первые две буквы в слове равны введеному сочетанию букв. Выведите ок, если это так, и не ок, если не так.
#
# **7** Вводится название группы, в которой обязательно только 6 символов. БМЭ214. С новой строки вводится переменная года - две последние цифры года, например 21. Нужно проверить, что группа соответствует году, когда студенты поступили.
#
# **8** Вводится дата, в формате 21.05.2021. С новой строки вводится год, нужно вывести ок, если дата относится к этому году, в ином случае - не ок.

# %% [markdown]
# **9** Вводится строка и число, если длина слова больше или равна введенному числу, выводим ок, в обратном случае - не ок

# %% [markdown]
# **10** Вводятся все слова на проверку приставки по: если вторая буква в слове равна "а", вывести "ошибка", в обратном случае - 'все хорошо'

# %% [markdown]
# **11** Пароль является валидным, если в нем не менее 10 символов и он состоит только из букв. Вывести "валиден", если условие выполняется, "не валиден", если нет

# %% [markdown]
# ## Задание 10

# %% [markdown]
# **1** Помогите студенту понять, что оценка ниже 4 - это пересдача. Вводятся положительные числа, пока не введется число 0. Если число меньше 4, нужно вывести строку "Пересдача", в обратном случае - 'Все в порядке'

# %% [markdown]
# **2** Поочередно вводятся целые числа, не превышающие по значению 100.
# Необходимо вывести только те числа, которые нечетные и при этом делятся на 3.
# Если вводится число больше 100, цикл прекращает работу.

# %% [markdown]
# **3** Напишите программу, которая будет запрашивать на ввод слово до тех пока не будет введет 'КОНЕЦ'. Если слово начинается на букву 'б', его нужно вывести.

# %% [markdown]
# **4** Вводится последовательность чисел, которая заканчивается словом "end". Необходимо вывести только те числа, в которых есть цифра 2.

# %% [markdown]
# **5** Вводится последовательность слов, которая оканчивается словом КОНЕЦ. Выведите только те слова, в которых нет буквы «а»

# %% [markdown]
# **6** Напишите программу, которая будет запрашивать на ввод слово до тех пор, пока не будет введено слово "end".После того, как было введено слово "end", программа должна вывести количество введенных слов (не считая "end").

# %% [markdown]
# **7** Дан пустой список new_list. Затем вводится последовательность чисел, пока не введется 0. Нужно добавить в список new_list целлочисленоное деление на 2 только тех чисел, которые являются нечетными.

# %% [markdown]
# **8** Дан пустой список new_list. Затем вводится последовательность строк, пока не введется ноль. Нужно проверить, если в строке есть слово "привет", то строку нужно добавить в список new_list.

# %%
*из базового добавить**

# %% [markdown]
# ## Задание 11

# %% [markdown]
# **1** Вводится список предметов студента, затем с новой строки - название предмета. Если предмета нет в списке, его нужно добавить в список, а затем вывести список через пробел.

# %% [markdown]
# **2** Вводится список слов. Из списка нужно удалить те элементы, в которых есть только цифр и вывести полученный список

# %% [markdown]
# **3** Реализуйте программу, которая определяет номер слова в строке. На первой строке вводится фраза. Гарантируется, что в строке нет знаков препинания, а разделителями между словами служат пробелы. На второй строке вводится слово. Программа находит номер слова в фразе, если это слово в ней есть, и печатает этот номер (нумерация идет с 1). Слово проверяется с учетом регистра. Если такого слова в строке нет, программа печатает 99.

# %% [markdown]
# **4** Вводится кортеж, затем с новой строки слово. Если слово есть в кортеже, его нужно удалить и вывести слова слитно.

# %% [markdown]
# ## Задание 12

# %% [markdown]
# **1** Вводится список предметов, для каждого предмета нужно проверить, если он начинается на П и в нем 5 символов, тогда нужно вывести строку: "Черт, питон меня догнал!"

# %% [markdown]
# **2** Считывается список паролей, которая Анна придумала для своей корпоративной почты,
# и строка year с годом ее рождения.
# Нужно вывести только те пароли, в которых не указан год ее рождения
# и которые не имеют больше трех букв "а".
# 'arrjkd2003', 'aaa2003fjk', '2005fffa', 'aaafjfjdl', 'frjb'.

# %% [markdown]
# **4** Вводится список слов, а затем с новой строки - буква. Нужно вывести те элементы из списка, в которых введенная буква встречается 2 и более раз.

# %% [markdown]
# **5** Вводится список имен, если имя состоит из 4 буквы, выводим его

# %% [markdown]
# **6** Вводится список слов, а затем с новой строки - буква. Нужно добавить в новый список те элементы, которые заканчиваются на введенную букву и вывести через запятую и пробел отсортированный против алфавита полученный список

# %% [markdown]
# **7** Вводится список, нужно вывести только те элементы, в которых находятся только цифры. Каждый элемент вывести с новой строки

# %% [markdown]
# **8** Вводится список телефонных номеров. Например, каждый номер выглядит так: 8(985)175-17-68. Затем с новой строки вводится сразу три числа. Нужно проверить, записаны ли эти числа в скобочках у номера. Вывести количество номеров, в которых есть эти числа.

# %% [markdown]
# ## Задание 13

# %% [markdown]
# **1** Вводится два списка одинаковой длины. В одном хранятся имена студентов, во втором - курс на который они ходят весь семестр. Нужно вывести строку вида "X посещает Y", где X - имя студента из списка с индексом i, Y - название предмета из списка предметов с индексом i.

# %% [markdown]
# **2** Реализуйте программу, которая фильтрует респондентов на основе показателя их дохода:
# На первой строке через запятую и пробел вводятся имена респондентов.
# На второй строке через запятую и пробел вводятся вещественные числа — доход респондентов. Каждое значение соответствует респонденту.
# Далее вводится значение дохода (целое число), которое не должны превышать доходы респондента.
# Гарантируется, что будет введена информация минимум для одного респондента.
# Программа выводит имена респондентов, доход которых ниже введенного значения, каждое на новой строке.

# %% [markdown]
# **3** Вводится два списка. В одном находятся имена студентов, в другом - годы их рождения. Нужно вывести строки вида: Студенту <имя студента> исполнится в этом году <возраст>. Чтобы найти возраст: вычтите из 2023 года год рождения студента.

# %% [markdown]
# **4** Вводится два списка. В одном находятся имена студентов, в другом - курсы, которые они посещают. Каждый элемент одного списка соответствует элементу из другого списка. Нужно вывести строки вида: Студент <имя студента> посещает курс: <первые три буквы курса>.

# %% [markdown]
# **5** Реализуйте следующую программу:Считываются два списка одинаковой длины — names и books.
# В первом списке — имена, во втором — названия книг введенные через пробел.
# Этот код уже написан.
# Программа выводит строки вида "X читает Y",
# где X — строка из списка names под индексом i,
# а Y — строка из списка books под индексом i.
# Каждая строка вида "X читает Y" печатается на новой строке.

# %% [markdown]
# **10** Считываются два списка - names и data, а затем строка year.
# В первом списке - имена, во втором - год рождения.
# Нужно вывести имена только тех людей, которые родились в год, соответствующий
# переменной year.

# %% [markdown]
# **11** Вводится два списка одинаковой длины. В одном списке хранятся имена студентов, в другом - размер стипендии, которую получает каждый студент. Затем с новой строки вводится число - размер нормальной стипендии в 2023 году. Нужно вывести имена тех студентов, которые получают стипендию меньше нормальной.

# %% [markdown]
# **12** Вводятся два списка. В одном имена детей, в другом - игрушки, которые они хотят, разделенные дефисом. Выведите строки вида '<имя ребенка> хочет игрушку <первую по счету игрушку>'

# %% [markdown]
# **13** Вводится два списка. В одном - игрушки, которые хочет Вася, в другом списке находятся игрушки, которые могут купить родители. Выведите через запятую с пробелом те игрушки, которые хочет вася и их могут купить родители.

# %% [markdown]
# **14**. Вводятся два списка, в одном имена студентов, в другом - оценки студентов за три теста. Оценки каждого студента разделены дефисом: оценка1-оценка2-оценка. Нужно вывести фразу: Имя: <студент>, оценка за последний тест: <оценка>

# %% [markdown]
# **15** Вводятся два списка одинаковой длины. В одном у нас имена студентов, в другом - их оценка за питон. Нужно вывести только тех студентов, у которых оценка за питон больше 8.

# %% [markdown]
# ## Задание 14

# %% [markdown]
# **1** Вводятся два списка, в одном предметы, которые изучают филологи, в другом списке - журналисты. Выведите предметы, которые изучают ТОЛЬКО журналисты, через запятую и пробел в отсортированном порядке.

# %% [markdown]
# **2** Вводятся два списка, в одном предметы, которые изучают филологи, в другом списке - журналисты. Выведите предметы, которые изучают ТОЛЬКО журналисты и ТОЛЬКО филологи, через запятую и пробел в отсортированном порядке.

# %% [markdown]
# **3** Вводится два списка. В одном - игрушки, которые хочет Вася, в другом списке находятся игрушки, которые могут купить родители. Выведите через запятую с пробелом те игрушки, которые хочет вася, но их не могут купить родители.

# %% [markdown]
# **4** Вводятся два списка, в одном предметы, которые изучают филологи, в другом списке - журналисты. Выведите общее количество совместных предметов для филологов и журналистов.

# %% [markdown]
# **5** Вводятся два списка с числами. Нам нужно вывести все числа из этих списков через точку с запятой в отсортированном по убыванию порядке.

# %% [markdown]
# **6** Вводятся два списка, в одном имена студентов, заваливших питон, в другом - заваливших андан. Выведите через запятую с пробелом имена студентов, заваливших и питон и андан. Имена в двух списках могут повторяться.

# %% [markdown]
# **7** Вводятся два списка, в одном места, куда хочет поехать Катя, в другом - Маша. Выведите через точку с запятой места, в которых хочет побывать либо Катя, либо Маша, либо они вдвоем.

# %% [markdown]
# **8** Вводятся два списка в одном места, где хочет побывать Вася, в другом - его брат. Выведите названия только тех мест, которые хочет посетить Вася.

# %% [markdown]
# ## Задание 15

# %% [markdown]
# **1** Дан словарь, в котором ключи - студенты, а значения - список оценок. Нужно вывести имена только тех студентов, у которых есть оценка 4.

# %%
marks = {'Петя': [4, 6, 7, 8], 'Вова': [4, 6, 7, 10], 'Марина': [10, 10, 7, 10]}

# %% [markdown]
# **2** Дан словарь, в котором ключи - студенты, а значения - список оценок. Затем с новой строчки вводится оценка (от 1 до 10), нужно вывести имена тех студентов, у которых такая оценка встречается 2 и более раз.

# %%
marks = {'Петя': [4, 6, 7, 8], 'Вова': [4, 6, 7, 10], 'Марина': [10, 10, 7, 10]}
mark_filter = int(input())
# Out:
# 10
# Марина

# %% [markdown]
# **3** Дан словарь студентов, где ключи студенты, а значения - список их любимых произведений. Затем вводится строка с названием произведения и нужно найти количество студентов, которым нравится эта книга.

# %%
students = {'Олег': ['Гарри Поттер', 'Война и мир'],
           'Марина': ['Война и мир', 'Тихий Дон'], 
           'Витя': ['Тихий Дон', 'Гарри Поттер']}
novel = input()

# %% [markdown]
# **4** Есть словарь, в котором ключами являются имена студентов, а значениями - целые числа, их среднее арифм оценка. С новой строки вводится число, нужно вывести тех студентов, у которых среднее арифм оценка больше или равна введеноому число.

# %%
marks = {'Гарри': 12, 'Гермиона': 20}
passing_grade = int(input())

# %% [markdown]
# **5** Есть словарь, в котором ключами является предмет, а значениями - имя студента, который записан на этот курс. Нужно вывести те предметы, имя студента которых начинаются на букву Б.

# %%
subjects = {'Питон': 'Борис', 'Математика': 'Полина'}

# %% [markdown]
# **6** Вводится словарь, в котором ключи - имена студентов, а значения - список курсов, которые они выбрали в приоритетном порядке. Выведите имена тех студентов, которые в качестве приоритета номер один выбрали введеный курс.

# %%
students = {'Лиза': ['Питон', 'Литра'], 'Мария': ['Англ', 'Литра']}
course = input()

# %% [markdown]
# **7** Вводится словарь, в котором ключи - имена людей, а значения - кортежи, в которых два значения: год рождения и год смерти. С новой строки вводится определенный год смерти - нужно вывести всех людей, умерших в этот день.

# %%
people = {'Яна': (1980, 2020), 'Мария': {1950, 2010}}
year_of_death = int(input())

# %% [markdown]
# **8** Вводится словарь, в котором ключи имена студентов, а значения - годы их рождения. Выведите количество студентов, которые родились раньше введенного года.

# %%
students = {'Лиза': 1999, 'Мария': 2000}
year = int(input())

# %% [markdown]
# **9** Реализуйте программу, которая проверяет, насколько популярна языковая школа:
# Дан словарь schools, в котором ключами являются названия школ, а значениями — списки с количеством заявок на обучение за последнюю неделю. Гарантируется, что названия школ не повторяются. В переменную filter_cust считывается минимально допустимое суммарное количество заявок за неделю, чтобы школа не вышла в "минус". Этот код уже написан. Программа проверяет, что в статистике подачи заявок в школу нет дней с нулевым количеством заявок и что суммарное число заявок не ниже значения filter_cust, и выводит названия таких школ, каждое на новой строке. Если таких школ нет — программа ничего не выводит.

# %%
schools = {'ЯзыкДляВсех': [45, 67, 30, 24, 82, 12, 91], 
           'Питонисты2023': [32, 14, 29, 100, 21, 70, 25], 
           'EngStart': [105, 48, 22, 74, 53, 90, 12], 
           'NewLang': [83, 200, 0, 44, 12, 54, 19]}

filter_cust = int(input())

# %% [markdown]
# ## Задание 16

# %% [markdown]
# **1** Напишите функцию checker, которая принимает на вход слово и число и выводит True, если длина слова больше или равна числу, и False в обратном случае.

# %% [markdown]
# **2** Создайте функцию checker, которая принимает на вход два числа.
# Нужно проверить, если квадрат первого числа будет больше второго нужно вернуть True,
# или False в обратном случае.

# %% [markdown]
# **3** Напишите функцию check_password, которая принимает аргуменент —
# password (строка с паролем).
# Функция возвращает логическую константу True,
# если пароль состоит только из букв и False в ином случае.

# %% [markdown]
# **4** Напишите функцию checker, которая примет на вход список с названиями аккаунтов
# и вернет список тех аккаунтов, которые содержат '@'.

# %% [markdown]
# **5** Напишите функцию, которая поможет определить средние траты за все месяцы.
#
#
# ТРЕБУЕМАЯ ФУНКЦИЯ
# Функция get_data, параметром которой является список кортежей, каждый из которых состоит из двух элементов — строки (названия месяца) и целого числа (сколько денег за данный месяц было потрачено).
# Функция должна возвращать вещественное число — среднее значение трат за все указанные месяцы.

# %% [markdown]
# # Задачи С

# %% [markdown]
# ## Задание 17

# %% [markdown]
# **1**. Напишите функцию checker, которая принимает на вход список слов и букву и возвращает новый список, в котором находятся только те слова, в которых введенная буква встречается 4 раза.

# %% [markdown]
# **2** Учебный офис хочет посчитать среднюю оценку по конкретному предмету. Помогите им.
#
# ТРЕБУЕМАЯ ФУНКЦИЯ Функция get_average, которая принимает на вход целое число и словарь. Ключами словаря являются имена студентов, а значениями — списки оценок (целых чисел от 1 до 10). Гарантируется, что в словаре есть информация минимум об одном студенте. Гарантируется, что у всех студентов одинаковое количество оценок. Целое число — порядковый номер предмета (индекс) в списке оценок каждого студента, среднюю оценку за который нужно посчитать. Функция должна возвращать вещественное число — среднюю оценку по предмету среди всех студентов (сумму оценок по предмету разделить на количество студентов).

# %% [markdown]
# **3** Напишите функцию checker, которая принимает на вход список оценок и возвращает True, если в списке нет оценок 4 и 5, а оценка 6 встречается не более 4 раз. Программа выведет False в обратном случае.

# %% [markdown]
# **4** Задание 17. Помогите блогеру Сене выбрать из подписок в инстаграме аккаунты с определенными размерами аудитории, чтобы отправить предложение о сотрудничестве.
# ТРЕБУЕМАЯ ФУНКЦИЯ
#
# Функция filter_accounts, которая принимает в качестве параметра словарь accounts, ключами которого являются адреса аккаунтов, а значениями — число подписчиков. Также функция принимает в качестве параметров целые числа min_followers и max_followers, где min_followers меньше либо равен max_followers. Функция должна возвращать список адресов аккаунтов, где число подписчиков находится в промежутке между min_followers и max_followers включительно, адреса должны быть отсортированы в лексикографическом порядке.

# %% [markdown]
# ## Задание 18

# %% [markdown]
# **1** Вводится строка с информацией про студентов и выбранный ими майнор. В строке данные разделены запятой с пробелом. Информация о каждом студенте записана в виде 'имя студента' / 'его майнор'. С новой строчки вводится название определенного майнора, нужно вывести список с именами студентов, которые ходят на этот майнор.

# %% [markdown]
# **2**. Вводится число n. Затем вводится n строк, в которых информация о друзьях Васи и где они живут (в строке информация разделена пробелом). Затем с новой строчки вводится страна, нужно вывести количество друзей Васи, которые живут в этой стране.

# %% [markdown]
# ## Задание 19-20

# %% [markdown]
# **1.19**. Есть файл students.csv, в котором хранится информация об имени студента, его месте жительства и баллах егэ, каждая информация разделена запятой. выведите строки с информацией о студентах, у которых баллы егэ больше 300, каждое с новой строки.

# %% [markdown]
# **1.20**. Есть файл students.csv, в котором хранится информация об имени студента, город проживания и баллах егэ, каждая информация разделена запятой. Затем вводится строка с городом. Найдите процентное соотношение между всеми студентами из этого и студентами из этого города, получивших больше 300 баллов.
