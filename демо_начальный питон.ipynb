# %% [markdown]
# **9** Вводится название книги, если ее название состоит только из букв, нужно вывести 'отлично', в другом случае - 'не подходит'

# %% [markdown]
# **9** Вводится цена за книгу, если цена находится в диапазоне от 100 до 500 рублей, то вася может ее купить, иначе не сможет.

# %% [markdown]
# **10** Поочередно вводятся строки, пока не введется 0. Нужно вывести количество тех слов, которые начинаются с буквы 'a' - проверяйте без учета регистра

# %% [markdown]
# **10** Дан пустой список new_list. Затем вводится последовательность чисел, пока не введется 0. Нужно добавить в список new_list целлочисленоное деление на 2 только тех чисел, которые являются нечетными.

# %% [markdown]
# **11** Вводится база книг в магазине (список), а затем с новой строки вводится название новой книги. Проверьте: добавили ли ее в базу и если нет - добавьте книгу в базу и выведите список в алфавитном порядке через запятую с пробелом

# %% [markdown]
# **11** В список книг Лермонтова случайно добавили не его прозведение - эта строка введена в переменную wrong_book. Проверьте, если она еще хранится в списке, удалите и выведите список книг лермонтова слитно

# %% [markdown]
# **12** Вводится список с названиями книг, посчитайте количество тех книг, в которых есть буква 'a'.

# %% [markdown]
# **12** Вводится список с ценами на книги, выведите количество тех цен,которые не больше 350.

# %% [markdown]
# **13** Вводятся два списка: в одном названия книг, в другом - имена их авторов. Нужно вывести строки вида: <автор> написал книгу <название книги>

# %% [markdown]
# **13** Вводятся два списка: в одном даты - годы рождения и смерти писателей, разделенных - (например 1870-1914). Во втором списке вводятся имена писателей. Нужно вывести строки типа: <писатель> родился в <год рождения> году

# %% [markdown]
# **13** Вводятся два списка: в одном годы рождения писателей, в другом - их имена. Нужно вывести имена только тех писателей, которые родились позже 1856 года.

# %% [markdown]
# **14** Вводятся два списка: в одном книги, которые нравятся андрюше, в другом - которые нравятся пете. Выведите те книги, которые нравятся мальчикам по отдельности, то есть только пете и только андрюше.

# %% [markdown]
# **14** Вводятся два списка: в одном книги, которые нравятся андрюше, в другом - которые нравятся пете. Выведите те книги, которые нравятся обоим мальчикам

# %% [markdown]
# **14** Вводятся два списка: в одном книги, которые нравятся андрюше, в другом - которые нравятся пете. Выведите те книги, которые нравятся только Пете

# %% [markdown]
# **15** Вводится словарь, в котором ключи - названия произведений, а значения - год их написания. Выведите только те книги, написанные в промежутке от 1800 до 1900 года.

# %%
books = {'Война и мир': 1865}

# %% [markdown]
# **15** Вводится словарь, в котором ключи названия произведения, а значения - список с ценами на эти книги в разных магазинах. C новой строки вводится целое число max_price - максимально допустимая цена. Выведите только те книги, максимальная цена которых превышает значение max_price

# %%
books = {'Война и мир': [350, 450, 670, 700]}
max_price = int(input())

# %% [markdown]
# **16** Определите функцию check, которая принимает два аргумента: кортеж, где первый элемент название книги, а второй ее цена. Вторым аргументом является сумма денег, которая есть у пети. Проверьте, может ли Петя купить книгу (то есть цена за книгу меньше или равна сумме денег, которая у него есть) и если да, верните True, в обратном случае выведите False
