# %% [markdown]
# # Задания B

# %% [markdown]
# ## Задание 9

# %% [markdown]
# **1** Реализуйте программу, которая проверяет, что в месяце 31 день или нет:
#
# Дан список months, где хранятся названия месяцев (строки), в которых 31 день. В переменную month2check считывается название месяца, который нужно проверить. Этот код уже написан. Если в месяце 31 день, программа печатает строку 'В месяце 31 день.' Если введенный месяц февраль — программа печатает строку 'В месяце 28 или 29 дней.' В остальных случах программа печатает строку 'В месяце 30 дней.'

# %%
months = ['январь', 'март', 'май', 'июль', 'август', 'октябрь', 'декабрь']
month2check = input()

# %% [markdown]
# **2** Маши и Риты есть списки десертов, на которые у них аллергия. Реализуйте программу, которая проверяет, закажут девочки десерт в кафе или нет.
# Даны списки masha и rita, где хранятся названия десертов, на которые у каждой девочки соответственно есть аллергия. Вводится название десерта, который подается в выбранном ими кафе. Если десерт находится хотя бы в одном из списков, программа печатает строку 'Нет, идем в другое кафе'.  В остальных случаях программа печатает строку 'Да, делаем заказ!'.

# %% [markdown]
# **3** Реализуйте программу, которая проверяет, доставляет ли транспортная компания товары в необходимый город:
#
# Дан список cities, где хранятся названия городов (строки), в которых есть филиалы нужной транспортной компании. На первой строке вводится название города, который нужно проверить. На второй строке вводится вес груза, который нужно доставить. Если город есть в списке, и вес не превышает 1000, то программа печатает фразу "Готовьте к отгрузке". Фраза сохранена для вас в переменную shipment. Если город есть в списке, но вес превышает 1000, то программа печатает фразу "Разделите на несколько посылок". Фраза сохранена для вас в переменную multiple_packages. Во всех остальных случаях программа печатает фразу "Обратитесь в другую компанию". Фраза сохранена для вас в переменную other_company.

# %%
cities = ['Москва', 'Пермь', 'Краснодар', 'Калининград', 'Якутск']

shipment = 'Готовьте к отгрузке'
multiple_packages = 'Разделите на несколько посылок'
other_company = 'Обратитесь в другую компанию'
city = input()
weight = int(input())

# %% [markdown]
# **4** Помогите бедному вышкинцу понять 10-балльную систему. Если студент получил оценку больше или равно 8, то у него 5, если получил от 6 до 7, то 4, если от 4 до 5, то 3. Вводится число в 10 балльной системе, вывести нужно число в 5-балльной.

# %% [markdown]
# **5** Вася - обычный студент. Поэтому он всегда голодный и хочет кофе. Напишите программу, которая поможет Васе понять, что он сможет купить себе в столовой. Если у Васи только 180 рублей, он может купить только обед, если у Васи больше 180, то он сможет купить и обед, и кофе. Если же у Васи меньше 180 рублей, он будет ждать стипу

# %% [markdown]
# ## Задание 10

# %% [markdown]
# **1** Поочередно вводятся строки в формате: 'имя студента-его год рождения-год поступления'. Добавьте в список normal имена тех студентов, которым в год их поступления было 18 и более лет. Выведите список в отсортированном порядке.

# %% [markdown]
# **2** Реализуйте программу, сохраняющую в список квадраты четных чисел:
#
# Задан пустой список squares. Этот код уже написан. В цикле while считываются целые положительные числа до тех пор, пока не введен 0 (не учитывается в последовательности). Для каждого вводимого числа сделайте проверку: если число четное — добавьте его в список squares. Гарантируется, что до 0 будет введено как минимум одно целое положительное число. Напечатайте список squares.

# %% [markdown]
# **3** Поочередно вводятся строки в формате <блюдо;его цена>. В список good_choice нужно добавить только те блюда, которые находятся в диапазоне от 500 до 1000 рублей.

# %% [markdown]
# **4** Поочередно вводятся строки пока не введется 0. Строки выглядят следующим образом: <название товара> <цена на рынке> <цена в магазине>. Нужно вывести список только тех товаров, у которых цена на рынке равна цене в магазине. Список отсортировать в обратном алфавиту порядке.

# %% [markdown]
# # Задание 11

# %% [markdown]
# **1** Реализуйте программу, которая фильтрует студентов на основе их года поступления в университет:
#
# В переменную students считывается список, где хранятся имена студентов (строки). Этот код уже написан. В переменную years считывается список, где хранятся целые числа — год начала обучения студентов в университете. Каждый год соответствует студенту из списка students. Этот код уже написан. Гарантируется, что будет введена информация минимум для одного студента. В переменную year2filter считывается число — год поступления, который нас интересует. Этот код уже написан. Программа выводит имена студентов, которые поступили в университет в год year2filter или позже, каждое на новой строке. Если таких студентов нет, то программа ничего не выводит.

# %% [markdown]
# **2** Вводятся два списка. В одном - названия картин, во втором - авторы картины. С новой строки вводится слово, если оно есть в названии картины, нужно вывести автора этой картины. Каждый элемент одного списка соответствует элементу из второго списка.

# %% [markdown]
# **3** Реализуйте программу, которая фильтрует респондентов на основе показателя их дохода: На первой строке через запятую и пробел вводятся имена респондентов. На второй строке через запятую и пробел вводятся вещественные числа — доход респондентов. Каждое значение соответствует респонденту. Далее вводится значение дохода (целое число), которое не должны превышать доходы респондента. Гарантируется, что будет введена информация минимум для одного респондента. Программа выводит имена респондентов, доход которых ниже введенного значения, каждое на новой строке.

# %% [markdown]
# **4**  Вводится два списка одинаковой длины. В одном списке хранятся имена студентов, в другом - размер стипендии, которую получает каждый студент. Затем с новой строки вводится число - размер нормальной стипендии в 2023 году. Нужно вывести имена тех студентов, которые получают стипендию меньше нормальной.

# %% [markdown]
# **5** Вводятся два списка. В одном имена детей, в другом - игрушки, которые они хотят, разделенные дефисом. Выведите строки вида '<имя ребенка> хочет игрушку <первую по счету игрушку>'

# %% [markdown]
# **6** Вводятся два списка, в одном имена студентов, в другом - оценки студентов за три теста. Оценки каждого студента разделены дефисом: оценка1-оценка2-оценка. Нужно вывести фразу: Имя: <студент>, оценка за последний тест: <оценка>

# %% [markdown]
# **7** Вводятся два списка одинаковой длины. В одном у нас имена студентов, в другом - их оценка за питон. Нужно вывести только тех студентов, у которых оценка за питон больше 8.

# %% [markdown]
# # Задание 12

# %% [markdown]
# **1** Реализуйте программу, которая помогает двум друзьям выбрать подходящее время для совместной поездки:
#
# В переменную months_vasya считывается список названий месяцев (строки) — время, когда Вася может поехать в отпуск. Этот код уже написан. В переменную months_dasha считывается список названий месяцев (строки) — время, когда Даша может поехать в отпуск. Этот код уже написан. В переменную bad_weather считывается список названий месяцев (строки) — время, когда в стране назначения плохая погода. Этот код уже написан. Гарантируется, что названия месяцев в каждом из трех списков уникальные и что в каждом списке есть как минимум одно название месяца. Выведите через запятую с пробелом названия месяцев, в которые Вася и Даша могут вместе поехать в отпуск при условии, что в месте назначения не плохая погода. Названия отсортируйте в алфавитном порядке.

# %% [markdown]
# **2** Вводятся два списка - курсы, преподаваемые первакам в 2020 и 2021 году. В третьем списке находятся предметы, которые убрали из пуда в 2022 году. Выведите названия тех предметов, которые преподавались и в 2020 и в 2021 году, но этом не были удалены из пуда.

# %% [markdown]
# **3** Вводятся два списка - курсы, преподаваемые первакам в 2020 и 2021 году. В третьем списке находятся предметы, которые убрали из пуда в 2022 году. Выведите названия тех предметов, которые преподавались либо в 2020 либо в 2021 году, либо в оба года, но этом были удалены из пуда.

# %% [markdown]
# **4** Вводятся два списка - курсы, преподаваемые первакам в 2020 и 2021 году. В третьем списке находятся предметы, которые убрали из пуда в 2022 году. Выведите названия тех предметов, которые преподавались только в 2021 году и не были удалены из пуда.

# %% [markdown]
# **5** Вводится два списка. В одном - игрушки, которые хочет Вася, в другом - его брат Андрюша. В третьем списке находятся игрушки, которые могут купить родители. Выведите через запятую с пробелом те игрушки, которые хотят оба мальчика и их могут купить родители.

# %% [markdown]
# **6** Вводятся два списка, в одном - места, которые хочет посетить Аня, во втором - Катя. В третьем списке вводятся бесплатные места. Выведите через запятую с пробелом в отсортированном порядке те места, которые нравятся либо Кате, либо Ане (либо им обеим) и которые бесплатные.

# %% [markdown]
# ##  Задание 13

# %% [markdown]
# **1** Вводится словарь, в котором ключи - имена студентов, а значения - список курсов, которые они выбрали в приоритетном порядке. Выведите имена тех студентов, которые в качестве приоритета номер один выбрали введенный курс.

# %%
students = {'Лиза': ['Питон', 'Литра'], 'Мария': ['Англ', 'Литра']}
course = input()

# %% [markdown]
# **2** Вводится словарь, в котором ключи - имена людей, а значения - кортежи, в которых два значения: год рождения и год смерти. С новой строки вводится определенный год смерти - нужно вывести список с именами всех людей, умерших в этот год.

# %%
people = {'Яна': (1980, 2020), 'Мария': (1950, 2010)}
year_of_death = int(input())

# %% [markdown]
# **3** Дан словарь courses, в котором ключами является курс, а значениями - словарь, в котором находится информация про год и количество студентов, получивших за курс 10. С новой строчки вводится год (этот код уже написан), нужно вывести суммарное количество студентов, посещавших курсы в заданный год.

# %%
courses = {'Питон':{2021:20,2022:40, 2023:50}, 
           'Литература':{2021:40, 2023:50},
           'Математика':{2020:50, 2023:40}}
year = int(input()) # 2021

# %% [markdown]
# **4** Дан словарь students, в котором ключи - имена студентов, в значениях - словарь с информацией про год и список курсов, которые посещал студент. с новой строчки вводит год (этот код уже написан), нужно вывести количество курсов, которые посещали студенты в заданный год

# %%
students = {'Олег': {2021:['Питон', 'Литература', 'Математика'], 2022: ['Литература', 'Математика']},
            'Марина': {2021:['Аудиорепортаж'], 2022: ['Литература']},
            'Витя': {2021:['Литература', 'Математика'], 2022: ['Питон', 'Аудиорепортаж']}}
year = int(input())

# %% [markdown]
# **5** Дан словарь presidents, в котором ключи - имя президента, а значения - список, в котором первый элемент - фракция определенного президента, второй элемент - начало правления, третий - конец. С новой строки вводится год, если он находится в промежутке правления одного из президентов, нужно вывести его фракцию

# %%
presidents={'wrbj':['jreb', 1841, 1845]}
year = int(input())

# %% [markdown]
# ## Задание 14

# %% [markdown]
# **1** Помогите блогеру Сене выбрать из подписок в инстаграме аккаунты с определенными размерами аудитории, чтобы отправить предложение о сотрудничестве. ТРЕБУЕМАЯ ФУНКЦИЯ
# Функция filter_accounts, которая принимает в качестве параметра словарь accounts, ключами которого являются адреса аккаунтов, а значениями — число подписчиков. Также функция принимает в качестве параметров целые числа min_followers и max_followers, где min_followers меньше либо равен max_followers. Функция должна возвращать список адресов аккаунтов, где число подписчиков находится в промежутке между min_followers и max_followers включительно, адреса должны быть отсортированы в лексикографическом порядке.
