# %% [markdown]
# # Множества
#
# set
#
# Неупорядоченный тип данных.
#
# {‘c’, ‘d’, ‘s’}
#
# {‘d’, ‘c’, ‘s’}
#
# Это одно и то же множество.
#
#
# 1. Здесь нет индексов и срезов.
#
# 2. Можно использовать только УНИКАЛЬНЫЕ элементы. Если добавить то, что в множестве уже есть, ничего не изменится, двух таких элементов не будет.
#
# 3. Можно пользоваться  циклом for, len() и not(in). и сортировкой!
#
# **Как ввести множество?**
#
# a=set((input().split())
#
# или
#
# a = input().split()
#
# a = set(a)
#
# **Чтобы создать пустое множество**:
#
# a = set()
#
# **Чтобы вывести**
#
# set
#
# {1,2,3}
#
# *set
#
# a b c d
#
# ‘, ’.join(set)
#
# a, b, c, d
#
# *set, sep = ', '
#
# *set, sep = '\n'
#
# **Методы**
#
# .add() -  добавить
#
# .remove() - удалить
#
# a.add('мама')

# %% [markdown]
# # Самое важное: операции!!

# %% [markdown]
# Операции:
#
# a = кот, собака, удав
#
# b = кот, хомяк, попугай
#
# а)	Объединение (| или .union()): все элементы множеств без повторений
#
# кот, собака, удав, хомяк, попугай
#
# a.union(b)
#
# a|b, b|a
#
# c = a|b
#
# print(a|b)
#
# б)	Пересечение (& или .intersection()): элементы, которые есть и в одном, и в другом
#
# a&b, b&a
#
# a.intersection(b)
#
# кот
#
# в)	Разность (- или .difference) – что есть уникального в множестве без пересечения (смотря какой из какого вычитаем)
#
# A-B=собака, удав
#
# B-A=хомяк, попугай
#
# a.difference(b)
# b.difference(a)
#
# г) 	Симметричная разность (^ или  .symmetric_difference): все элементы, которые не входят в пересечение (не важно, какой из какого вычитаешь)
#
# A^B - собака, удав, хомяк, попугай
#
# B^A - собака, удав, хомяк, попугай
#
# Можно с несколькими множествами.
#
# a&b&c
#
# a|b|c

# %% [markdown]
# # Словари

# %% [markdown]
# dict
#
# в словаре могут быть только уникальные ключи (значения могут повторяться)
#
# b= {‘d’:1, ‘c’:2, ‘a’:2}
#
# d - это ключ
# 1 - значение
#
# Неупорядоченные типы данных. Нет интервалов, срезов. Но можно использовать цикл for, len, in. Все эти штучки относятся и рассматривают КЛЮЧИ
#
# Если хотим обратиться к значению, то используем следующую схему - b['d']
#
# В цикле for i это ключ словаря. Для обращения к значению - b[i].
#
# for i in b: # i = d,c,a
#
#      if b[i]==1: # b[i] = 1,2,2
#
#         print(ok)
#
# if 'd' in b
#
# **создать пустой словарь**
#
# b = {}
#
# b = dict()
#
# **Добавить элемент:**
#
# <название словаря >[ключ]=значение
#
# b[‘v’]=3
#
# b['d'] +=1
#
# b['c'] = [1,2,3]
#
# b['c'].append(4)
#
#
# **Удалить элемент:**
#
# del b[‘d’]
#
# **что нужно помнить???**
#
# КЛЮЧОМ МОЖЕТ БЫТЬ ТОЛЬКО НЕИЗМЕНЯЕМЫЙ ТИП ДАННЫХ
# ЗНАЧЕНИЕМ - ВСЁ ЧТО УГОДНО
#
# **Методы .values(), .keys()** - кортежи из ТОЛЬКО значений и ключей СООТВЕТСТВЕННО
#
# b.values(), b.keys()
#
# Использовать с ними методы и другое, например min(b.values())
#
# **Метод .items()** - кортежи - пары ключ-значение (1,2)

# %%
b= {'d':1, 'c':2, 'a':2}
b.items()
# Out:
# dict_items([('d', 1), ('c', 2), ('a', 2)])

# %% [markdown]
# Роли, выполняемые объектами в словаре
#
# Числа (int/float) - ключ и значение, неизм тип данных: int - 1, float - 1.5, 2.5
#
# Строки - ключ и значение, неизм тип данных - str 'мама', '123'
#
# Кортеж - ключ и значение, неизм тип данных - tuple ('b', 1, True)
#
# Список - только значение, изм тип данных - list ['b', 1, True]
#
# Множество - только значение, изм тип данных - set {1, 2, 'wb'}
#
# Словарь - только значение, изм тип данных - dict {'v':1, 'd':2}
#
# Логические переменные (True, False) - ключ и значение, неизм тим данных - bool True, False

# %%
a = 'мама'
a = a.replace('м', 'п')
a
# Out:
# 'папа'

# %% [markdown]
# # Задачи

# %% [markdown]
# ## Словари

# %% [markdown]
# Задача 1. Дан словарь minors, в котором ключи — имена студентов (строки), а значения — названия майноров, которые они выбрали (строки).
# В переменную minor_to_search считывается название интересующего нас майнора — этот код уже написан.
# Напечатайте имена всех студентов из словаря minors, выбравших определенный майнор, каждое с новой строки. Имена выводятся в том же порядке, в котором они хранятся в словаре.
# Если таких студентов нет, то программа ничего не печатает.

# %%
minors = {'Лика Иванова': 'ИАД', 'Алексей Петров': 'Антропология',
          'Василий Сидоров': 'Этика', 'Михаил Лермонтов': 'ИАД', 
          'Лари Дмитриева': 'Театр с нуля', 
          'Мария Константинова': 'Антропология',
          'Алексей Плющенко': 'Квантовый микромир', 
          'Михаил Ковтун': 'Квантовый микромир',
          'Лариса Дериглазова': 'ИАД', 'Андрей Иванов': 'UX-дизайн', 
          'Никита Смирнов': 'Исследователь в EdTech', 
          'Анна Романова': 'Театр с нуля'
          }

minor_to_search = input()
for i in minors:
    if minors[i] == minor_to_search:
        print(i)
# Out:
# Театр с нуля
# Лари Дмитриева
# Анна Романова

# %%
for key, value in minors.items():
    if value == minor_to_search:
        print(key)
# Out:
# Лари Дмитриева
# Анна Романова

# %% [markdown]
# Реализуйте программу, находящую исполнителя по названию песни:
#
# Дан словарь playlist, в котором ключами являются имена исполнителей (строки), а значениями — списки названий песен (строки). Гарантируется, что названия песен не повторяются. В переменную song считывается название песни. Этот код уже написан. Программа проверяет наличие песни song в словаре и выводит имя ее исполнителя. Если такой песни среди значений словаря нет — программа ничего не выводит.

# %%
playlist = {'Radwimps': ['Suzume', 'Sparkle'],
           'Иван Дорн': ['Мозоль', 'Бигуди', 'Вставай'],
           'Кино': ['Звезда по имени солнце', 'Восьмиклассница', 'Кукушка', 'Перемен'],
           'Queen': ['Show must go on'],
           'Клава Кока': ['Краш', 'Мурашки']}
song = input()
# Out:
# Бигуди
# Иван Дорн

# %% [markdown]
# Дан словарь, в котором ключами является онлайн-курс, а значениями - имена студентов. Затем с новой строки вводится имя конкретного студента, нужно вывести список курсов, на которые записан этот студент.

# %%
courses = {'Питон': ['Алиса', 'Марина', 'Олег'], 
           'Литература': ['Олег', 'Марина', 'Алина', 'Влад'],
           'Философия': ['Олег', 'Алиса', 'Максим'],
           'Психология': ['Алиса', 'Максим']}
name = input()
new = []
for i in courses:
    if name in courses[i]:
        new.append(i)
print(new)
# Out:
# Олег
# 3

# %% [markdown]
# В переменной books хранится словарь, ключами которого являются названия книг, а значениями — их авторы.
#
# Напишите программу, которая принимает на вход некоторую непустую строку и выводит все книги, для которых введенная строка содержится либо в названии, либо в имени автора. Поиск не чувствителен к регистру ("Гарри" и "гарри" — разные запросы). Если совпадений нет, программа ничего не выводит.
#
# ФОРМАТ ВВОДА
#
# Непустая строка ФОРМАТ ВЫВОДА
#
# Авторы и названия книг, удовлетворяющие условию, каждая пара на новой строке.

# %%
books = {   'Сильмариллион': 'Джон Толкин', 
            'Гарри Поттер и кубок огня': 'Джоан Роулинг', 
            'Неукротимая планета': 'Гарри Гаррисон', 
            'Человек без лица': 'Альфред Бестер', 
            "Алиса в стране чудес": "Льюис Кэрролл", 
            "Космическая Одиссея": "Артур Кларк", 
            "Дюна": "Фрэнк Герберт", 
            "Двадцать тысяч лье под водой": "Жюль Верн", 
            "Янки из Коннектикута при дворе короля Артура": "Марк Твен", 
            "Американские боги": "Нил Гейман", 
            "Хроники Амбера": "Роджер Желязны", 
            "Хроники Нарнии": "Клайв С. Льюис", 
            "Война миров": "Герберт Уэллс" }
# если бы поиск был ЧУВСТВИТЕЛЕН к регистру
word = input().lower()
for i in books:
    if word in i.lower() or word in books[i].lower():
        print(i, books[i])

# %% [markdown]
# Задача из экзамена 13

# %%
plane = input()
s=0
for i in airlines:
    for b in airlines[i]:
        if b == plane:
            s+=len(airlines[i][b])
print(s)

# %% [markdown]
# ## Множества

# %% [markdown]
# Задача 1
#
# Реализуйте программу, которая помогает выбрать подходящее время для совместной поездки:
#
# В переменную months_vasya считывается список названий месяцев (строки) — время, когда Вася может поехать в отпуск. Этот код уже написан.
# В переменную months_dasha считывается список названий месяцев (строки) — время, когда Даша может поехать в отпуск. Этот код уже написан.
# Гарантируется, что названия месяцев в каждом списке уникальные и что в каждом списке есть как минимум одно название месяца.
# Выведите через запятую с пробелом названия месяцев, в которые Вася и Даша могут вместе поехать в отпуск. Названия отсортируйте в алфавитном порядке.

# %%
months_vasya = set(input().split())
months_dasha = set(input().split())
result = months_vasya & months_dasha
print(*sorted(result), sep=', ')
# Out:
# апрель май март
# май сентябрь март
# май, март

# %% [markdown]
# Задача 2
#
# Считываются два списка уникальных целых чисел — numbers_1 и numbers_2. Этот код уже написан. Гарантируется, что в каждом из множеств есть как минимум одно число.
# Преобразуйте каждый из списков в множество.
# Найдите все уникальные числа, которые входят хотя бы в одно из двух множеств.
# Отсортируйте по возрастанию и выведите числа из объединения двух множеств на одной строке через пробел.

# %%
numbers_1 = set(map(int,input().split()))
numbers_2  = set(map(int,input().split()))
result = numbers_1 | numbers_2 
print(*sorted(result))
# Out:
# 4 5 6
# 6 7 8
# 4 5 6 7 8

# %% [markdown]
# Поочередно вводится две последовательности целых чисел, разделенных пробелом. Выведите через пробел элементы, которые встречаются и в первом, и во втором.

# %%
numbers_1 = set(map(int,input().split()))
numbers_2  = set(map(int,input().split()))
result = numbers_1  & numbers_2
print(*result)

# %% [markdown]
# 1 2 3
#
# 3 2 5
#
# 3 2

# %% [markdown]
# Вводятся списки spells_1 и spells_2 - заклинания, которые Гермиона учила за первый и второй месяц. Выведите только те заклинания, которые Гермиона учила только на втором месяце. Выведите отсортированный в обратном порядке список, через запятую с пробелом.

# %%
spells_1 = set(input().split())
spells_2 = set(input().split())
result = spells_2 - spells_1
print(*sorted(result, reverse = True), sep = ', ')
# Out:
# питон литра жаба
# литра монтаж англ
# монтаж, англ

# %% [markdown]
# Задача 3
#
# Реализуйте следующую программу:
# Заданы два списка фамилий студентов, посещающих соответственно кружок по рисованию (students_1) и спортивную секцию (students_2). Этот код уже написан.
# Гарантируется, что фамилии студентов внутри одного списка не повторяются.
# Программа должна выводить одно целое число — общее количество уникальных студентов, которые записаны на оба кружка.

# %%
students_1 = set(input().split())
students_2 = set(input().split())
result = students_1 | students_1 
print(len(result))
# Out:
# Ленин Печорин Онегин
# Сталин Дзержинский Печорин Онегин
# 5
